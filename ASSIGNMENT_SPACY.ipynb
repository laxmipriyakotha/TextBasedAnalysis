# %% [markdown]
# #  <CENTER>ASSIGNMENT SPACY</CENTER>

# %% [markdown]
# # IMPORTING SPACY

# %% [markdown]
# SPACY IS AN OPEN-SOURCE NATURAL LANGUAGE PROCESSING LIBRARY FOR PYTHON.LOADING THE ENGLISH LANGUAGE MODEL 'en_core_web_lg' USING SPACY.

# %%
#!python -m spacy download en_core_web_lg 
import spacy
nlp = spacy.load("en_core_web_lg")

# %% [markdown]
# # SMALL TEXT

# %% [markdown]
# TOKENIZATION AND PART-OF-SPEECH TAGGING PERFORMED ON THE INPUT TEXT "MY BEST FRIEND RYAN PETERS LIKES FANCY ADVENTURE GAMES" USING SPACY.

# %%
text = "My best friend Ryan Peters likes fancy adventure games."
doc = nlp(text)
for token in doc:
    print(token, end="| ")
# Out:
# My| best| friend| Ryan| Peters| likes| fancy| adventure| games| .|

# %% [markdown]
# # ATTRIBUTES OF SPACY

# %% [markdown]
# GENERATING A DATAFRAME VISUALIZATION OF TOKENIZED TEXT WITH LEMMATIZATION, PART-OF-SPEECH TAGGING, AND ENTITY RECOGNITION USING SPACY.

# %%
import pandas as pd

def display_nlp(doc, include_punct=False):
    """Generate data frame for visualization of spaCy tokens."""
    rows = []
    for i, t in enumerate(doc):
        if not t.is_punct or include_punct:
            row = {'token': i,  'text': t.text, 'lemma_': t.lemma_, 
                   'is_stop': t.is_stop, 'is_alpha': t.is_alpha,
                   'pos_': t.pos_, 'dep_': t.dep_, 
                   'ent_type_': t.ent_type_, 'ent_iob_': t.ent_iob_}
            rows.append(row)
    
    df = pd.DataFrame(rows).set_index('token')
    df.index.name = None
    return df
display_nlp(doc)
# Out:
#         text     lemma_  is_stop  is_alpha   pos_      dep_ ent_type_ ent_iob_
# 0         My         my     True      True   PRON      poss                  O
# 1       best       good    False      True    ADJ      amod                  O
# 2     friend     friend    False      True   NOUN     nsubj                  O
# 3       Ryan       Ryan    False      True  PROPN  compound    PERSON        B
# 4     Peters     Peters    False      True  PROPN     appos    PERSON        I
# 5      likes       like    False      True   VERB      ROOT                  O
# 6      fancy      fancy    False      True    ADJ      amod                  O
# 7  adventure  adventure    False      True   NOUN  compound                  O
# 8      games       game    False      True   NOUN      dobj                  O

# %% [markdown]
# # REMOVING STOP WORDS USING SPACY

# %% [markdown]
# FILTERING OUT STOP WORDS AND PUNCTUATION SYMBOLS FROM THE INPUT TEXT "DEAR RYAN, WE NEED TO SIT DOWN AND TALK. REGARDS, PETE" USING SPACY.

# %%
text = "Dear Ryan, we need to sit down and talk. Regards, Pete"
doc = nlp(text)

non_stop = [t for t in doc if not t.is_stop and not t.is_punct]
print(non_stop)
# Out:
# [Dear, Ryan, need, sit, talk, Regards, Pete]

# %% [markdown]
# # FINDING NOUNS USING SPACY

# %% [markdown]
# EXTRACTING NOUNS AND PROPER NOUNS FROM THE INPUT TEXT "MY BEST FRIEND RYAN PETERS LIKES FANCY ADVENTURE GAMES" USING SPACY.

# %%
text = "My best friend Ryan Peters likes fancy adventure games."
doc = nlp(text)

nouns = [t for t in doc if t.pos_ in ['NOUN', 'PROPN']]
print(nouns)
# Out:
# [friend, Ryan, Peters, adventure, games]

# %% [markdown]
# # NAMED ENTITY RECOGNITION

# %% [markdown]
# IDENTIFYING AND PRINTING NAMED ENTITIES ALONG WITH THEIR LABELS IN THE INPUT TEXT "MY BEST FRIEND RYAN PETERS LIKES FANCY ADVENTURE GAMES" USING SPACY.

# %%
text = "My best friend Ryan Peters likes fancy adventure games."
doc = nlp(text)

for ent in doc.ents:
    print(f"({ent.text}, {ent.label_})", end=" ")
# Out:
# (Ryan Peters, PERSON)

# %% [markdown]
# # NAMED ENTITY RECOGNITION

# %%
text = "James O'Neill, chairman of World Cargo Inc, lives in San Francisco." 
doc = nlp(text)

for ent in doc.ents:
    print(f"({ent.text}, {ent.label_})", end=" ")
# Out:
# (James O'Neill, PERSON) (World Cargo Inc, ORG) (San Francisco, GPE)

# %% [markdown]
# # VISUALIZING NMR

# %% [markdown]
# VISUALIZING THE NAMED ENTITIES IN THE INPUT TEXT "MY BEST FRIEND RYAN PETERS LIKES FANCY ADVENTURE GAMES" USING SPACY'S `displacy.render()` FUNCTION IN A JUPYTER NOTEBOOK ENVIRONMENT.

# %%
from spacy import displacy

displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James O'Neill
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , chairman of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World Cargo Inc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , lives in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     San Francisco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</div></span>

# %% [markdown]
# # TOPIC -1
# # CNN NEWS ARTICLE

# %% [markdown]
# THIS CODE DEFINES A FUNCTION `URL_TO_STRING` THAT EXTRACTS TEXT CONTENT FROM A GIVEN URL USING BEAUTIFULSOUP AND REGULAR EXPRESSIONS, EXCLUDING CERTAIN ELEMENTS LIKE SCRIPTS, STYLES, AND ASIDES. THEN IT RETRIEVES THE TEXT FROM THE NDTV NEWS ARTICLE URL PROVIDED, PROCESSES IT USING SPACY, AND COUNTS THE NUMBER OF NAMED ENTITIES FOUND IN THE ARTICLE.

# %%
from bs4 import BeautifulSoup
import requests
import re
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))
ny_bb = url_to_string("https://www.cnn.com/world/egypt-new-administrative-capital-spc-intl/index.html")
article = nlp(ny_bb)
len(article.ents)
# Out:
# 243

# %% [markdown]
# # NERS

# %%
displacy.render(article, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Egypt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ’s
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New Administrative Capital
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# : A new city is rising, but is it what the country needs? |
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  values your feedback
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . How relevant is this ad to you?
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . Did you encounter any technical issues?                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Video player was slow to load content                                                                                                                                                                                                                                                                                                                                                             Video content never loaded                                                                                                                                                                                                                                                                                                                                                             Ad froze or did not finish loading                                                                                                                                                                                                                                                                                                                                                             Video content did not start after ad                                                                                                                                                                                                                                                                                                                                                             Audio on ad was too loud                                                                                                                                                                                                                                                                                                                                                             Other issues                                                                                                                                                                                                                                                                                                                                                                                                                                                               Ad never loaded                                                                                                                                                                                                                                                                                                                                                             Ad prevented/slowed the page from loading

# %% [markdown]
# # NER TYPE

# %%
from collections import Counter

# Get labels of named entities
labels = [x.label_ for x in article.ents]

# Count occurrences of each label
label_counts = Counter(labels)

# Print label counts
print(label_counts)
# Out:
# Counter({'ORG': 54, 'GPE': 46, 'PERSON': 25, 'CARDINAL': 22, 'DATE': 19, 'LOC': 18, 'EVENT': 16, 'WORK_OF_ART': 12, 'QUANTITY': 9, 'MONEY': 9, 'NORP': 7, 'PERCENT': 2, 'ORDINAL': 2, 'TIME': 1, 'FAC': 1})

# %% [markdown]
# # MOST POPULAR NER OF DATASET

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(5)
# Out:
# [('CNN', 19), ('Cairo', 15), ('Egypt', 10), ('Abbas', 7), ('ACUD', 6)]

# %% [markdown]
# # SENTENCE TO ANALYSE

# %%
sentences = [x for x in article.sents]
print(sentences[0])
# Out:
#                               Egypt’s New Administrative Capital: A new city is rising, but is it what the country needs?

# %% [markdown]
# # NER TAGS

# %% [markdown]
# RENDERS THE NAMED ENTITIES IN THE FIRST SENTENCE PARSED BY SPACY USING THE 'ENT' STYLE IN A JUPYTER NOTEBOOK.

# %%
displacy.render(nlp(str(sentences[0])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Egypt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ’s
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New Administrative Capital
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# : A new city is rising, but is it what the country needs?</div></span>

# %% [markdown]
# # TYPE OF WORDS IN SENTENCE

# %% [markdown]
# GENERATES A LIST COMPREHENSION THAT ITERATES OVER TOKENS IN THE FIRST SENTENCE PARSED BY SPACY, EXCLUDING STOP WORDS AND PUNCTUATION, AND EXTRACTS THEIR ORTHOGRAPHIC FORMS, PARTS OF SPEECH, AND LEMMATIZED FORMS, RETURNING THEM AS TUPLES.

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[0])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('                              ', 'SPACE', '                              '),
#  ('Egypt', 'PROPN', 'Egypt'),
#  ('New', 'PROPN', 'New'),
#  ('Administrative', 'PROPN', 'Administrative'),
#  ('Capital', 'PROPN', 'Capital'),
#  ('new', 'ADJ', 'new'),
#  ('city', 'NOUN', 'city'),
#  ('rising', 'VERB', 'rise'),
#  ('country', 'NOUN', 'country'),
#  ('needs', 'VERB', 'need')]

# %% [markdown]
# # SENTENCE DEPENDENCY TREE

# %% [markdown]
# VISUALIZES THE DEPENDENCY TREE OF A SENTENCE USING SPACY'S 'DISPLACY' RENDERER IN A JUPYTER NOTEBOOK WITH CUSTOMIZED DISTANCE BETWEEN NODES.

# %%
displacy.render(nlp(str(sentences[0])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="43bc757d0fa2400f8c8e94520f18febb-0" class="displacy" width="2210" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">                              </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Egypt</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">New</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">Administrative</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Capital:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">new</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">city</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">rising,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">but</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">what</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">country</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">needs?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-43bc757d0fa2400f8c8e94520f18febb-0-0" stroke-width="2px" d="M70,182.0 C70,122.0 160.0,122.0 160.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-43bc757d0fa2400f8c8e94520f18febb-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-43bc757d0fa2400f8c8e94520f18febb-0-1" stroke-width="2px" d="M190,182.0 C190,2.0 650.0,2.0 650.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-43bc757d0fa2400f8c8e94520f18febb-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,184.0 L182,172.0 198,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-43bc757d0fa2400f8c8e94520f18febb-0-2" stroke-width="2px" d="M190,182.0 C190,122.0 280.0,122.0 280.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-43bc757d0fa2400f8c8e94520f18febb-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M280.0,184.0 L288.0,172.0 272.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-43bc757d0fa2400f8c8e94520f18febb-0-3" stroke-width="2px" d="M430,182.0 C430,62.0 645.0,62.0 645.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-43bc757d0fa2400f8c8e94520f18febb-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,184.0 L422,172.0 438,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-43bc757d0fa2400f8c8e94520f18febb-0-4" stroke-width="2px" d="M550,182.0 C550,122.0 640.0,122.0 640.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-43bc757d0fa2400f8c8e94520f18febb-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,184.0 L542,172.0 558,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-43bc757d0fa2400f8c8e94520f18febb-0-5" stroke-width="2px" d="M670,182.0 C670,2.0 1250.0,2.0 1250.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">

# %% [markdown]
# # TOPIC 2
# # CHINESE NEWS ARTICLE

# %%
import spacy

# Load the Chinese language model
nlp = spacy.load("zh_core_web_lg")

from bs4 import BeautifulSoup
import requests
import re

def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

# URL of the CNN article
cnn_article_url = "https://www.bjnews.com.cn/detail/1710951770168244.html"

# Get the text content from the URL
article_text = url_to_string(cnn_article_url)

# Process the text using the Chinese language model
article = nlp(article_text)

# %%
# Count the number of named entities in the article
num_entities = len(article.ents)
print("Number of named entities in the article:", num_entities)
# Out:
# Number of named entities in the article: 215

# %%
displacy.render(article, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">﻿
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     新京报
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  - 好新闻，无止境
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     新京号
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#                                   电子报                                  千龙网
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     贝壳
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 财经
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     北京BEIJING
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     新京
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 雅集                                   专题                                  商务合作                                  爱心模式                                                                                                                                                                                                                                                               客户端                                                                                                                                                                                     微博                                                                        微信                                                                                                                                                                                 首页                  视频                  深读                  公益                  时事
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     第一
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# 看点                  政事儿
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     北京                  国际                  观点                  财经                  食品                  商业                  娱乐                  文化                  体育                  汽车                  房产                  酒业                  教育                  健康                  图说                  科技                  智库                  乡村
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# 首页                          &gt; 房产
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     石家庄
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 、
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     惠州
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 回调房贷利率，利率较高城市存在进一步下调空间                                                                                                2024-03-
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     21 00
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# :
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     22
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#                                                                                              记者：
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     张建
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#     编辑：武新                                                                                                                                                                                                                                                                                                                                                                                                                                    业内人士表示，房贷利率较高的城市未来存在进一步下调的空间和预期。
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3月19日
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ，一份《关于调整
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     石家庄市
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 差别化住房信贷政策的通知》（简称《通知》）在业内流传，其中提到，自
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2024年4月份
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# 起，
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     石家庄市
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 恢复执行全国统一的首套住房商业性个人住房贷款利率下限，
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     二
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; ve

# %%
from collections import Counter

# Get labels of named entities
labels = [x.label_ for x in article.ents]

# Count occurrences of each label
label_counts = Counter(labels)

# Print label counts
print(label_counts)
# Out:
# Counter({'CARDINAL': 52, 'GPE': 51, 'DATE': 41, 'ORG': 31, 'PERSON': 18, 'LAW': 5, 'PERCENT': 3, 'MONEY': 3, 'WORK_OF_ART': 2, 'ORDINAL': 2, 'TIME': 2, 'QUANTITY': 2, 'FAC': 1, 'LOC': 1, 'NORP': 1})

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(5)
# Out:
# [('石家庄', 22), ('3', 12), ('惠州', 11), ('LPR', 7), ('新京报', 5)]

# %%
sentences = [x for x in article.sents]
print(sentences[0])
# Out:
# ﻿          新京报 - 好新闻，无止境                                                                                                                                                   新京号                                  电子报                                  千龙网                                  贝壳财经                                  北京BEIJING                                                   新京雅集                                   专题                                  商务合作                                  爱心模式                                                                                                                                                                                                                                                               客户端                                                                                                                                                                                     微博                                                                        微信                                                                                                                                                                                 首页                  视频                  深读                  公益                  时事                  第一看点                  政事儿                  北京                  国际                  观点                  财经                  食品                  商业                  娱乐                  文化                  体育                  汽车                  房产                  酒业                  教育                  健康                  图说                  科技                  智库                  乡村                                                                                               首页                          > 房产                                                                   石家庄、惠州回调房贷利率，利率较高城市存在进一步下调空间                                                                                                2024-03-21 00:22                                                                                             记者：张建    编辑：武新                                                                                                                                                                                                                                                                                                                                                                                                                                    业内人士表示，房贷利率较高的城市未来存在进一步下调的空间和预期。

# %%
displacy.render(nlp(str(sentences[0])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">﻿
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     新京报
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  - 好新闻，无止境
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     新京号
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#                                   电子报                                  千龙网
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     贝壳
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 财经
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     北京BEIJING
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     新京
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 雅集                                   专题                                  商务合作                                  爱心模式                                                                                                                                                                                                                                                               客户端                                                                                                                                                                                     微博                                                                        微信                                                                                                                                                                                 首页                  视频                  深读                  公益                  时事
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     第一
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# 看点                  政事儿
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     北京                  国际                  观点                  财经                  食品                  商业                  娱乐                  文化                  体育                  汽车                  房产                  酒业                  教育                  健康                  图说                  科技                  智库                  乡村
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# 首页                          &gt; 房产
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     石家庄
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 、
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     惠州
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 回调房贷利率，利率较高城市存在进一步下调空间                                                                                                2024-03-
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     21 00
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# :
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     22
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#                                                                                              记者：
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     张建
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#     编辑：武新                                                                                                                                                                                                                                                                                                                                                                                                                                    业内人士表示，房贷利率较高的城市未来存在进一步下调的空间和预期。                                                                                                                                                                                                                                                                                            </div></span>

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[0])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('\ufeff', 'NOUN', ''),
#  ('         ', 'SPACE', ''),
#  ('新京报', 'PROPN', ''),
#  ('新闻', 'NOUN', ''),
#  ('无止', 'ADJ', ''),
#  ('境', 'NOUN', ''),
#  ('                                                                                                                                                  ',
#   'SPACE',
#   ''),
#  ('新京号', 'PROPN', ''),
#  ('                                 ', 'SPACE', ''),
#  ('电子报', 'NOUN', ''),
#  ('                                 ', 'SPACE', ''),
#  ('千龙网', 'PROPN', ''),
#  ('                                 ', 'SPACE', ''),
#  ('贝壳', 'NOUN', ''),
#  ('财经', 'NOUN', ''),
#  ('                                 ', 'SPACE', ''),
#  ('北京', 'PROPN', ''),
#  ('BEI', 'NOUN', ''),
#  ('JIN', 'PROPN', ''),
#  ('G', 'NOUN', ''),
#  ('                                                  ', 'SPACE', ''),
#  ('新京', 'PROPN', ''),
#  ('雅集', 'NOUN', ''),
#  ('                                  ', 'SPACE', ''),
#  ('专题', 'NOUN', ''),
#  ('                                 ', 'SPACE', ''),
#  ('商务', 'NOUN', ''),
#  ('合作', 'NOUN', ''),
#  ('                                 ', 'SPACE', ''),
#  ('爱心', 'NOUN', ''),
#  ('模式', 'NOUN', ''),
#  ('                                                                                                                                                                                                                                                              ',
#   'SPACE',
#   ''),
#  ('客户端', 'NOUN', ''),
#  ('                                                                                                                                                                                    ',
#   'SPACE',
#   ''),
#  ('微博', 'PROPN', ''),
#  ('                                                                       ',
#   'SPACE',
#   ''),
#  ('微信', 'NOUN', ''),
#  ('                                                                                                                                                                                ',
#   'SPACE',
#   ''),
#  ('首', 'NUM', ''),
#  ('页', 'NUM', ''),
#  ('                 ', 'SPACE', ''),
#  ('视频', 'NOUN', ''),
#  ('                 ', 'SPACE', ''),
#  ('深', 'ADV', ''),
#  ('读', 'VERB', ''),
#  ('                 ', 'SPACE', ''),
#  ('公益', 'NOUN', ''),
#  ('                 ', 'SPACE', ''),
#  ('时事', 'NOUN', ''),
#  ('                 ', 'SPACE', ''),
#  ('第一', 'ADV', ''),
#  ('点', 'NUM', ''),
#  ('                 ', 'SPACE', ''),
#  ('政事儿', 'PROPN', ''),
#  ('                 ', 'SPACE', ''),
#  ('北京', 'PROPN', ''),
#  ('                 ', 'SPACE', ''),
#  ('国际', 'NOUN', ''),
#  ('                 ', 'SPACE', ''),
#  ('观点', 'NOUN', ''),
#  ('                 ', 'SPACE', ''),
#  ('财经', 'NOUN', ''),
#  ('                 ', 'SPACE', ''),
#  ('食品', 'NOUN', ''),
#  ('                 ', 'SPACE', ''),
#  ('商业', 'NOUN', ''),
#  ('                 ', 'SPACE', ''),
#  ('娱乐', 'NOUN', ''),
#  ('                 ', 'SPACE', ''),
#  ('文化', 'NOUN', ''),
#  ('                 ', 'SPACE', ''),
#  ('体育', 'NOUN', ''),
#  ('                 ', 'SPACE', ''),
#  ('汽车', 'NOUN', ''),
#  ('                 ', 'SPACE', ''),
#  ('房产', 'NOUN', ''),
#  ('                 ', 'SPACE', ''),
#  ('酒业', 'NOUN', ''),
#  ('                 ', 'SPACE', ''),
#  ('教育', 'NOUN', ''),
#  ('                 ', 'SPACE', ''),
#  ('健康', 'NOUN', ''),
#  ('                 ', 'SPACE', ''),
#  ('图说', 'NOUN', ''),
#  ('                 ', 'SPACE', ''),
#  ('科技', 'NOUN', ''),
#  ('                 ', 'SPACE', ''),
#  ('智库', 'NOUN', ''),
#  ('                 ', 'SPACE', ''),
#  ('乡村', 'NOUN', ''),
#  ('                                                                                              ',
#   'SPACE',
#   ''),
#  ('首', 'NUM', ''),
#  ('页', 'NUM', ''),
#  ('                         ', 'SPACE', ''),
#  ('房产', 'NOUN', ''),
#  ('                                                                  ',
#   'SPACE',
#   ''),
#  ('石家庄', 'PROPN', ''),
#  ('惠州', 'PROPN', ''),
#  ('回调', 'VERB', ''),
#  ('房贷', 'NOUN', ''),
#  ('利率', 'NOUN', ''),
#  ('利率', 'NOUN', ''),
#  ('高', 'ADJ', ''),
#  ('城市', 'NOUN', ''),
#  ('进一步', 'ADJ', ''),
#  ('下调', 'VERB', ''),
#  ('空间', 'NOUN', ''),
#  ('                                                                                               ',
#   'SPACE',
#   ''),
#  ('2024', 'NUM', ''),
#  ('03', 'NOUN', ''),
#  ('21', 'NOUN', ''),
#  ('00', 'NOUN', ''),
#  ('22', 'NUM', ''),
#  ('                                                                                            ',
#   'SPACE',
#   ''),
#  ('记者', 'NOUN', ''),
#  ('张建', 'PROPN', ''),
#  ('\xa0\xa0\xa0\xa0', 'SPACE', ''),
#  ('编辑', 'VERB', ''),
#  ('武新', 'PROPN', ''),
#  ('                                                                                                                                                                                                                                                                                                                                                                                                                                   ',
#   'SPACE',
#   ''),
#  ('业内', 'NOUN', ''),
#  ('人士', 'NOUN', ''),
#  ('房贷', 'NOUN', ''),
#  ('利率', 'NOUN', ''),
#  ('高', 'VERB', ''),
#  ('城市', 'NOUN', ''),
#  ('未来', 'NOUN', ''),
#  ('进一步', 'ADV', ''),
#  ('下调', 'VERB', ''),
#  ('空间', 'NOUN', ''),
#  ('预期', 'NOUN', ''),
#  ('                                                                                                                                                                                                                                                                                           ',
#   'SPACE',
#   '')]

# %%
displacy.render(nlp(str(sentences[0])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="zh" id="a082e21650c34977bca4292ac35ecf47-0" class="displacy" width="17210" height="1397.0" direction="ltr" style="max-width: none; height: 1397.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">﻿</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">         </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">新京报 -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">好</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">新闻，</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">无止</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">境</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">                                                                                                                                                  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">新京号</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">                                 </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">电子报</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">                                 </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">千龙网</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">                                 </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">贝壳</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">财经</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">                                 </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">北京</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">BEI</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">JIN</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">G</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">                                                  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">新京</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">雅集</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">                                  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">专题</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">                                 </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">商务</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">合作</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1307.0">
#     <tspan class="displa

# %% [markdown]
# # TOPIC 3
# # CNN NEWS ON POLITICS

# %%
from bs4 import BeautifulSoup
import requests
import re
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))
ny_bb = url_to_string("https://www.cnn.com/2024/03/10/politics/us-not-anticipating-israel-rafah-ramadan/index.html?iid=cnn_buildContentRecirc_end_recirc")
article = nlp(ny_bb)
len(article.ents)
# Out:
# 156

# %%
displacy.render(article, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">                              Rafah operation: US not
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     anticipating
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  I
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sraeli
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  forces to enter city at start of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ramadan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  |
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN Politics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  values your feedback                                                                                                                                                                                                                             1. How relevant is this ad to you?
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . Did you encounter any technical issues?                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Video player was slow to load content                                                                                                                                                                                                                                                                                                                                                             Video content never loaded                                                                                                                                                                                                                                                                                                                                                             Ad froze or did not finish loading                                                                                                                                                                                                                                                                                                                                                             Video content did not start after ad                                                                                                                                                                                                                                                                                                                                                             Audio on ad was too loud                                                                                                                                                                                                                                                                                                                                                             Other issues                                                                                                                                                                                                                                                                                                                                                                                                                                                               Ad never loaded                                                                                                                                                                                                                                                                                                                                                             Ad prevented/slowed the page from loading

# %%
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'ORG': 72,
#          'PERSON': 57,
#          'GPE': 10,
#          'CARDINAL': 5,
#          'DATE': 5,
#          'FAC': 4,
#          'TIME': 2,
#          'QUANTITY': 1})

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(5)
# Out:
# [('CNN', 28),
#  ('Rafah', 11),
#  ('sraeli', 8),
#  ('anticipating', 3),
#  ('Ramadan', 3)]

# %%
sentences = [x for x in article.sents]
print(sentences[20])
# Out:
# outlet Bild that the operation would not last more than two months but did not provide specifics on the timeline.

# %%
displacy.render(nlp(str(sentences[20])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     outlet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Bild that the operation would not last more than two months but did not provide specifics on the timeline.                       </div></span>

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[20])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('outlet', 'ADJ', ''),
#  ('Bild', 'PROPN', ''),
#  ('that', 'PRON', ''),
#  ('the', 'DET', ''),
#  ('operation', 'VERB', ''),
#  ('would', 'ADP', ''),
#  ('not', 'ADP', ''),
#  ('last', 'PROPN', ''),
#  ('more', 'ADJ', ''),
#  ('than', 'ADJ', ''),
#  ('two', 'NOUN', ''),
#  ('months', 'NOUN', ''),
#  ('but', 'CCONJ', ''),
#  ('did', 'PROPN', ''),
#  ('not', 'ADP', ''),
#  ('provide', 'VERB', ''),
#  ('specifics', 'VERB', ''),
#  ('on', 'ADP', ''),
#  ('the', 'DET', ''),
#  ('timeline', 'NOUN', ''),
#  ('                      ', 'SPACE', '')]

# %%
displacy.render(nlp(str(sentences[20])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="zh" id="0b8324f6d77e4fe68031a27f61f8fa6a-0" class="displacy" width="2570" height="557.0" direction="ltr" style="max-width: none; height: 557.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">outlet</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Bild</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">operation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">would</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">not</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">last</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">more</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">than</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">two</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">months</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">but</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">did</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">not</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">provide</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">specifics</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">timeline.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">                      </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">SPACE</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0b8324f6d77e4fe68031a27f61f8fa6a-0-0" stroke-width="2px" d="M70,422.0 C70,2.0 1850.0,2.0 1850.0,422.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0b8324f6d77e4fe68031a27f61f8fa6a-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,424.0 L62,412.0 78,412.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0b8324f6d77e4fe68031a27f61f8fa6a-0-1" stroke-width="2px" d="M190,422.0 C190,62.0 1845.0,62.0 1845.0,422.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0b8324f6d77e4fe68031a27f61f8fa6a-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,424.0 L182,412.0 198,412.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0b8324f6d77e4fe68031a27f61f8fa6a-0-2" stroke-width="2px" d="M190,422.0 C190,362.0 260.0,362.0 260.0,422.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0b8324f6d77e4fe68031a27f61f8fa6a-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M260.0,424.0 L268.0,412.0 252.0,412.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0b8324f6d77e4fe68031a27f61f8fa6a-0-3" stroke-width="2px" d="M430,422.0 C430,242.0 1230.0,242.0 1230.0,422.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0b8324f6d77e4fe68031a27f61f8fa6a-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,424.0 L422,412.0 438,412.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0b8324f6d77e4fe68031a27f61f8fa6a-0-4" stroke-width="2px" d="
