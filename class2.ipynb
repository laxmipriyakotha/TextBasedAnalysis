# %% [markdown]
# # CLASSWORK WEEK-2

# %% [markdown]
# ## DATA  EXPLORATION AND MANIPULATION
# Pandas is a Python library used for working with data sets.
# It has functions for analyzing, cleaning, exploring, and manipulating data.

# %%
import pandas as pd  # importing pandas for data exploration, manipulation
file="un-general-debates-blueprint.csv"
df= pd.read_csv(file)
df.head(20) # This command is used to display the first 20 rows of your DataFrame.
# Out:
#     session  year country                     country_name  \
# 0        25  1970     ALB                          Albania
# 1        25  1970     ARG                        Argentina
# 2        25  1970     AUS                        Australia
# 3        25  1970     AUT                          Austria
# 4        25  1970     BEL                          Belgium
# 5        25  1970     BLR                          Belarus
# 6        25  1970     BOL  Bolivia, Plurinational State of
# 7        25  1970     BRA                           Brazil
# 8        25  1970     CAN                           Canada
# 9        25  1970     CMR                         Cameroon
# 10       25  1970     COG                            Congo
# 11       25  1970     COL                         Colombia
# 12       25  1970     CRI                       Costa Rica
# 13       25  1970     CUB                             Cuba
# 14       25  1970     DOM               Dominican Republic
# 15       25  1970     DZA                          Algeria
# 16       25  1970     ECU                          Ecuador
# 17       25  1970     FRA                           France
# 18       25  1970     GBR                   United Kingdom
# 19       25  1970     GHA                            Ghana
#
#                   speaker    position  \
# 0                 Mr. NAS         NaN
# 1      Mr. DE PABLO PARDO         NaN
# 2             Mr. McMAHON         NaN
# 3      Mr. KIRCHSCHLAEGER         NaN
# 4              Mr. HARMEL         NaN
# 5          Mr. GURINOVICH         NaN
# 6      Mr. CAMACHO OMISTE         NaN
# 7      Mr. GIBSON BARBOZA         NaN
# 8               Mr. SHARP         NaN
# 9              Mr. AHIDJO  President
# 10            Mr. ICKONGA         NaN
# 11  Mr. VASQUEZ CARRIZOSA         NaN
# 12              Mr. FACIO         NaN
# 13            Mr. ALARCON         NaN
# 14        Mr FERNANDEZ G.
# 15              Mr. YAZID         NaN
# 16            Mr. Benites         NaN
# 17           Mr. SCHUMANN         NaN
# 18   Sir Alec DOUGLASHOME         NaN
# 19              Mr. OWUSU         NaN
#
#                                                  text
# 0   33: May I first convey to our President the co...
# 1   177.\t : It is a fortunate coincidence that pr...
# 2   100.\t  It is a pleasure for me to extend to y...
# 3   155.\t  May I begin by expressing to Ambassado...
# 4   176. No doubt each of us, before coming up to ...
# 5   \n71.\t. We are today mourning the untimely de...
# 6   135.\t  I wish to congratulate the President o...
# 7   1.\tMr. President, I should like, first of all...
# 8   \nThe General Assembly is fortunate indeed to ...
# 9   : A year ago I came here as the Acting Preside...
# 10  122.\t  I cannot begin my intervention without...
# 11  Mr. President, this visit to the United Nation...
# 12  62.\t  Mr. President, your election to the Pre...
# 13  1.\t  Mr. President, I should first like to co...
# 14  \n\n\n Mr. President, it was a source of great...
# 15  1.  The delegation of Algeria is very pleased ...
# 16  71.  It had been my hope that a loftier person...
# 17  84.\t  Within one month, when we celebrate the...
# 18  110.\t Mr. President, I should like first to s...
# 19  121.\t I should like to begin by congratulatin...

# %% [markdown]
# ## DISPLAYING COLUMNS
# The df.columns attribute is used to get the column labels of the DataFrame.
# This can be useful to see the names of all the columns in your DataFrame.

# %%
df.columns # gives column names
# Out:
# Index(['session', 'year', 'country', 'country_name', 'speaker', 'position',
#        'text'],
#       dtype='object')

# %% [markdown]
# ## DISPLAYING INFORMATION
#
# The df.info() method provides a concise summary of the DataFrame,
#  including information about the data types, non-null values, and memory usage

# %%
df.info() # gives information about dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7507 entries, 0 to 7506
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   session       7507 non-null   int64
#  1   year          7507 non-null   int64
#  2   country       7507 non-null   object
#  3   country_name  7507 non-null   object
#  4   speaker       7480 non-null   object
#  5   position      4502 non-null   object
#  6   text          7507 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 410.7+ KB

# %% [markdown]
# ##  DISPLAYING DATATYPES
# The df.dtypes attribute is used to display the data type of each column in the DataFrame.

# %%
df.dtypes # describes datatypes of data
# Out:
# session          int64
# year             int64
# country         object
# country_name    object
# speaker         object
# position        object
# text            object
# dtype: object

# %% [markdown]
# ## FUNCTION DESCRIBE
#
# The df.describe() method provides a statistical summary of the numerical columns i
#  your DataFram like  count, mean, standard deviation minimum, and maximum values

# %%
df.describe() #  gives description of the data in the DataFrame
# Out:
#            session         year
# count  7507.000000  7507.000000
# mean     49.610763  1994.610763
# std      12.892155    12.892155
# min      25.000000  1970.000000
# 25%      39.000000  1984.000000
# 50%      51.000000  1996.000000
# 75%      61.000000  2006.000000
# max      70.000000  2015.000000

# %% [markdown]
# ## CREATING LENGTH COLUMN

# %%
df['length'] = df['text'].str.len()  
#This will result in a new column that contains the length of each text entry in the 'text' column.
df.describe()
# Out:
#            session         year        length
# count  7507.000000  7507.000000   7507.000000
# mean     49.610763  1994.610763  17967.281604
# std      12.892155    12.892155   7860.038463
# min      25.000000  1970.000000   2362.000000
# 25%      39.000000  1984.000000  12077.000000
# 50%      51.000000  1996.000000  16424.000000
# 75%      61.000000  2006.000000  22479.500000
# max      70.000000  2015.000000  72041.000000

# %%
df.describe(include='O')
#It will provide summary statistics for all the non-numeric columns present in your specific dataset.
# Out:
#        country country_name        speaker                      position  \
# count     7507         7507           7480                          4502
# unique     199          199           5428                           113
# top        ALB      Albania  Seyoum Mesfin  Minister for Foreign Affairs
# freq        46           46             12                          1813
#
#                                                      text
# count                                                7507
# unique                                               7507
# top     33: May I first convey to our President the co...
# freq                                                    1

# %% [markdown]
# ## USING FILLNA TO FILL NULL VALUES

# %%
df['speaker'].fillna('unknown', inplace=True)
df['position'].fillna('unknown', inplace=True)
df.isna().sum() # we have filled the null values in the dataframe
# Out:
# C:\Users\laxmi\AppData\Local\Temp\ipykernel_12960\793846407.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['speaker'].fillna('unknown', inplace=True)
# C:\Users\laxmi\AppData\Local\Temp\ipykernel_12960\793846407.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['position'].fillna('unknown', inplace=True)
# session         0
# year            0
# country         0
# country_name    0
# speaker         0
# position        0
# text            0
# length          0
# dtype: int64

# %% [markdown]
# ## CAPITALIZING STRINGS

# %%
df['speaker'] = df['speaker'].str.upper()
df['position'] = df['position'].str.upper() # manipulating the string to upper cases accordingly
df['text'] = df['text'].str.upper()

# %% [markdown]
# ## SEARCHING WORD BUSH

# %%
df[df['speaker'].str.contains('BUSH')] # here we get output coulmns containing word bush
# Out:
#       session  year country   country_name             speaker   position  \
# 2720       44  1989     USA  United States                BUSH  PRESIDENT
# 2876       45  1990     USA  United States         GEORGE BUSH    UNKNOWN
# 3038       46  1991     USA  United States         GEORGE BUSH  PRESIDENT
# 3207       47  1992     USA  United States     MR. GEORGE BUSH  PRESIDENT
# 4814       56  2001     USA  United States      GEORGE W. BUSH  PRESIDENT
# 5002       57  2002     USA  United States  MR. GEORGE W. BUSH  PRESIDENT
# 5191       58  2003     USA  United States      GEORGE W. BUSH  PRESIDENT
# 5382       59  2004     USA  United States   MR. GEORGE W BUSH  PRESIDENT
# 5760       61  2006     USA  United States  MR. GEORGE W. BUSH  PRESIDENT
# 5951       62  2007     USA  United States      GEORGE W. BUSH  PRESIDENT
# 6143       63  2008     USA  United States      GEORGE W. BUSH  PRESIDENT
#
#                                                    text  length
# 2720  ﻿I AM HONOURED TO ADDRESS THE GENERAL ASSEMBLY...   19779
# 2876  ﻿\nIT IS REALLY A GREAT PRIVILEGE TO GREET YOU...   15843
# 3038  ﻿I AM HONOURED TO SPEAK WITH YOU AS YOU OPEN T...   15555
# 3207  FORTY-SEVEN YEARS AGO I WAS A YOUNG MAN OF 21,...   21105
# 4814  ﻿WE MEET IN A HALL DEVOTED TO\nPEACE; IN A CIT...   14724
# 5002  ﻿WE MEET ONE YEAR AND ONE DAY\nAFTER A TERRORI...   16684
# 5191  ﻿TWENTY-FOUR MONTHS AGO, AND\nYESTERDAY IN THE...   16962
# 5382  THANK YOU FOR THE HONOUR OF\nADDRESSING THE GE...   18628
# 5760  I AM GRATEFUL FOR THE PRIVILEGE OF \nSPEAKING ...   16675
# 5951  THANK YOU FOR THE OPPORTUNITY \nTO ADDRESS THE...   15483
# 6143  I AM PLEASED TO BE HERE TO \nADDRESS THE GENER...   18384

# %% [markdown]
# ## PLOTTING
# plot() function in pandas to create a simple line plot.

# %% [markdown]
# Matplotlib is a cross-platform, data visualization and graphical plotting library (histograms, scatter plots, bar charts, etc) for Pytho..

# %%
import matplotlib as mb # importing matplotlib for visualizations 
df['length'] = df['text'].str.len() #This will result in a new column that contains the length of each text entry in the 'text' column.
df.describe()
# Out:
#            session         year        length
# count  7507.000000  7507.000000   7507.000000
# mean     49.610763  1994.610763  17967.281870
# std      12.892155    12.892155   7860.038437
# min      25.000000  1970.000000   2362.000000
# 25%      39.000000  1984.000000  12077.000000
# 50%      51.000000  1996.000000  16424.000000
# 75%      61.000000  2006.000000  22479.500000
# max      70.000000  2015.000000  72041.000000

# %% [markdown]
# ## POINT TO LINE PLOT

# %%
import matplotlib as mb 
df['length'].plot(kind= 'line',legend=True)
#plot() function in pandas to create a simple line plot.
# Add labels and a title
mb.pyplot.xlabel('Length')
mb.pyplot.ylabel('Frequency')
mb.pyplot.title('line of Length')
# Show legend with a label
mb.pyplot.legend(['Length'])
# Display the plot
mb.pyplot.show()

# %% [markdown]
# ## BOXPLOT
# n
# Box plots provide a quick visual summary of the variability of values in a dataset
# . They show the median, upper and lower quartiles, minimum and maximum values
# , and any outliers in the dataset. Outliers can reveal mistakes or unusual occurrences in data.

# %%
import matplotlib as mb 
df['length'].plot(kind='box', vert=False)  # boxplot for given data
mb.pyplot.xlabel('frequency')
mb.pyplot.title('box of Length')
# Show legend with a label
mb.pyplot.legend(['Length'])
# Display the plot
mb.pyplot.show()

# %% [markdown]
# ## HISTOGRAM
# A histogram is a graph showing frequency distributions.
# It is a graph showing the number of observations within each given interval.

# %%
df['length'].plot(kind='hist', bins=30, alpha=0.7, legend=True)
# Add labels and a title
mb.pyplot.xlabel('Length')
mb.pyplot.ylabel('Frequency')
mb.pyplot.title('Histogram of Length')
# Show legend with a label
mb.pyplot.legend(['Length'])
# Display the plot
mb.pyplot.show()

# %% [markdown]
# ## SEABORN
# Seaborn is a Python data visualization library based on matplotlib.
# It provides a high-level interface for drawing attractive and informative statistical graphics.

# %%
import seaborn as sns  # importing seaborn for making statistical graphics
where = df['country'].isin(['USA', 'FRA', 'GBR', 'CHN', 'RUS'])
g = sns.catplot(data=df[where], x="country", y="length", kind='box')
g.fig.set_size_inches(10, 8) 
#positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Out:
# C:\Users\laxmi\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %% [markdown]
# ## USING REGEX
# n
# A RegEx, or Regular Expression, is a sequence of characters that forms a search patter
# . RegEx can be used to check if a string contains the specified search pattern

# %%
import regex as re # importing and using regex for  matching and extracting string patterns

def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)

# %% [markdown]
# ## TESTTOKENS

# %%
testtext = "Let's defeat SARS-CoV-2 together in 2020! www.cdc.gov"
testtokens = tokenize(testtext) # splitting up a larger body of text into smaller lines, words or even creating words for a non-English language.
 
print(testtokens)
# Out:
# ['Let', 's', 'defeat', 'SARS-CoV-2', 'together', 'in', 'www', 'cdc', 'gov']

# %% [markdown]
# ## IMPORTING NLTK PACAKAGE
#  variety of tasks can be performed using NLTK such as tokenizing, parse tree visualization,

# %%
import nltk # importing Natural Language Toolkit for  which helps in tokenization..
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {'isn', 'there', 'being', 'once', 'yours', 'further', 'can', 'up', 'who', 'himself', 'same', 'does', 'didn', 'her', 'too', 'an', 'should', 'i', 'in', 'such', 'more', 'which', 'that', 'am', 'y', 'and', 'as', 'what', 'doing', 'with', 'no', 'its', 'hasn', "couldn't", 'itself', 'needn', 'if', 'why', 'will', 'theirs', 'other', 'she', 'me', 'the', 'these', 'any', 'has', 'yourself', "wouldn't", 'hers', 'was', 'my', 'had', "hasn't", 'have', 'won', "you'll", 'against', 'through', 've', 'here', 'aren', 'just', 'couldn', "that'll", 'his', 'where', 'below', "aren't", 'after', 'don', 're', 'of', 'between', "hadn't", 'their', 'not', 't', 'few', "mustn't", 'some', 'our', "isn't", 'when', "weren't", "didn't", 'shouldn', 'were', 'on', 'from', 'or', 'to', 'having', 'them', 'all', 'is', 'only', 'your', 'until', "doesn't", 'ourselves', 'out', 'him', 'are', 'shan', 'those', 'over', 'mustn', 'ain', 'haven', 'now', 'during', 'into', 'yourselves', "needn't", 'while', 'd', "you're", 'wasn', 'herself', "she's", 'how', 'll', "shan't", 'did', 'than', 'own', 'ma', 'hadn', 'very', 'wouldn', 'under', 'so', 'it', 'by', 'again', 'about', 'weren', 'whom', 'then', 'but', 'above', "wasn't", "won't", 'doesn', 'themselves', 'each', "shouldn't", 'before', 'they', 'myself', 'he', 'do', 'm', 'because', 'nor', "should've", 'at', 'most', 'ours', 'be', 'off', 'been', 'we', 'this', 's', "haven't", "you'd", "mightn't", 'mightn', 'both', "it's", 'for', "don't", 'down', 'o', 'a', 'you', "you've"}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\laxmi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## STOP WORDS

# %%
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]
#Just testing it
cleantokens= remove_stop(testtokens)
print(cleantokens)
# Out:
# ['Let', 'defeat', 'SARS-CoV-2', 'together', 'www', 'cdc', 'gov']

# %% [markdown]
# ## TOKENS

# %%
pipeline = [str.lower, tokenize, remove_stop]

def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens

# %% [markdown]
# ## TEXT PREPROCESSING PIPELINE

# %%
df['tokens'] = df['text'].apply(prepare, pipeline=pipeline)
df['num_tokens'] = df['tokens'].map(len)
df.tail()
# returns last rows
# Out:
#       session  year country  country_name                            speaker  \
# 7502       70  2015     YEM         Yemen  MR. ABDRABUH MANSOUR HADI MANSOUR
# 7503       70  2015     YUG    Yugoslavia               MR. TOMISLAV NIKOLIĆ
# 7504       70  2015     ZAF  South Africa                         JACOB ZUMA
# 7505       70  2015     ZMB        Zambia             MR. EDGAR CHAGWA LUNGU
# 7506       70  2015     ZWE      Zimbabwe                      ROBERT MUGABE
#
#        position                                               text  length  \
# 7502  PRESIDENT  ON BEHALF OF THE PEOPLE AND THE GOVERNMENT OF ...   10568
# 7503  PRESIDENT  \nSEVENTY YEARS HAVE PASSED SINCE THE ESTABLIS...   25430
# 7504  PRESIDENT  I SHOULD LIKE TO CONGRATULATE THE PRESIDENT AN...   13662
# 7505  PRESIDENT  I WOULD LIKE TO BEGIN BY THANKING THE SECRETAR...   14247
# 7506  PRESIDENT  ALLOW ME AT THE OUTSET TO EXTEND TO MR. MOGENS...   11013
#
#                                                  tokens  num_tokens
# 7502  [behalf, people, government, yemen, would, lik...         894
# 7503  [seventy, years, passed, since, establishment,...        2118
# 7504  [like, congratulate, president, country, denma...        1160
# 7505  [would, like, begin, thanking, secretary-gener...        1197
# 7506  [allow, outset, extend, mr, mogens, lykketoft,...         903

# %% [markdown]
# ## USING COLLECTION AND IMPORTING COUNTER
#
# Counter. A Counter is a data type in the collections module. It is a dict subclass that stores counts for hashable objects.

# %%
from collections import Counter # importing counter to count variables

tokens = tokenize("She likes my cats and my cats like my sofa.")

testcount= Counter(tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %% [markdown]
# ## TOKENIZATION
# Tokenization is a preprocessing technique in natural language processing (NLP).
# It breaks down unstructured text data into smaller units called tokens.

# %%
more_tokens = tokenize("She likes dogs and cats.")
testcount.update(more_tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 3, 'She': 2, 'likes': 2, 'and': 2, 'like': 1, 'sofa': 1, 'dogs': 1})

# %% [markdown]
# ## MAPPING

# %%
counter = Counter() #It is used to count the occurrences of elements in a collection (typically a list or string).
df['tokens'].map(counter.update)
print(counter.most_common(5))
# Out:
# [('nations', 124508), ('united', 120763), ('international', 117223), ('world', 89421), ('countries', 85734)]

# %% [markdown]
# ## TOKENIZATION

# %%
freq_df = pd.DataFrame.from_dict(counter, orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'token'

# %%
freq_df = freq_df.sort_values('freq', ascending=False) # sorting according to frequency
freq_df.head(10)
# Out:
#                  freq
# token
# nations        124508
# united         120763
# international  117223
# world           89421
# countries       85734
# peace           72625
# development     62632
# states          59713
# people          59338
# security        58425

# %% [markdown]
# ## DESCRIPTION

# %%
freq_df.describe() 
#The df.describe() method provides a statistical summary of the numerical columns.
# Out:
#                 freq
# count   68302.000000
# mean      162.686276
# std      1544.080072
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%        15.000000
# max    124508.000000

# %% [markdown]
# ## PLOTTING FREQUENCY

# %%
ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8)) # Selects the top 15 rows from your frequency DataFrame.
ax.invert_yaxis() # Inverts the y-axis to display the highest frequencies at the top.
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words') #Sets labels and a title for the plot.
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %% [markdown]
# ## WORDCLOUD
# .
# Word cloud is one of the most powerful and straightforward visualization methods when it comes to text data
# . The size of words are dependent on the occurrence frequency

# %%
from wordcloud import WordCloud 
#importing word cloud 
# wordcloud used for visualization  to display tags or keywords
from matplotlib import pyplot as plt
text = df.query("year==2015 and country=='USA'")['text'].values[0]
plt.figure(figsize=(15,10)) ###  Sets up a Matplotlib figure with a specified size of 14x7 inches.
wc = WordCloud(background_color='black', width = 600, height=600, max_words=100, margin=2,stopwords=stopwords)
#Creates a WordCloud object with a maximum of 100 words and uses the provided stopwords
wc.generate(text) #Generates the word cloud from the text data.
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 599.5, 599.5, -0.5)

# %% [markdown]
# ## WORDCLOUD 2

# %%
wc = WordCloud(background_color='white', width = 600, height=600, max_words=100, margin=2)
wc.fit_words(freq_df['freq'].to_dict() ) # Fits the words and their frequencies from the DataFrame to the WordCloud object.
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wc) #Displays the word cloud using Matplotlib.
plt.axis("off")
plt.tight_layout(pad = 0) # Adjusts the layout to avoid clipping of the word cloud.
plt.show()
